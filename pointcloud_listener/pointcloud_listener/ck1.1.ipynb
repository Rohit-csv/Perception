# %%
#this code trains a neural network on mnist data
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
#load the data set
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_train[0])
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# 5

# %%
# Normalize pixel values from [0, 255] → [0, 1]
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0
# the normalization is done to speed up training and stabalizing gradient

# %%
# One-hot encode the labels (0–9 to vector of size 10)
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
#It helps the model treat each class as independent and learn probabilities for each class.

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),   # Flatten 28x28 image to 784-dim vector
    Dense(256, activation='relu'),   # Hidden layer 1
    Dense(128, activation='relu'),   # Hidden layer 2
    Dense(64, activation='relu'),    # Hidden layer 3
    Dense(10, activation='softmax')  # Output layer for 10 classes
])
#Relu = Rectified linear unit
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 3
#       1 model = Sequential([
#       2     Flatten(input_shape=(28, 28)),   # Flatten 28x28 image to 784-dim vector
# ----> 3     Dense(256, activation='relu'),   # Hidden layer 1
#       4     Dense(128, activation='relu'),   # Hidden layer 2
#       5     Dense(64, activation='relu'),    # Hidden layer 3
#       6     Dense(10, activation='softmax')  # Output layer for 10 classes
#       7 ])
#       8 #Relu = Rectified linear unit
#
# File ~/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:95, in Dense.__init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, lora_rank, lora_alpha, **kwargs)
#      93 super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ...

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 model.compile(optimizer='adam',
#       2               loss='categorical_crossentropy',
#       3               metrics=['accuracy'])
#
# NameError: name 'model' is not defined

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
