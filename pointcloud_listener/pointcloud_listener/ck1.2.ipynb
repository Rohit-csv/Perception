# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# Load dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Reshape to (samples, 28, 28, 1) for CNN input and normalize
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Load dataset
# ----> 2 (x_train, y_train), (x_test, y_test) = mnist.load_data()
#       4 # Reshape to (samples, 28, 28, 1) for CNN input and normalize
#       5 x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
#
# NameError: name 'mnist' is not defined

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),  # Conv layer
    MaxPooling2D((2, 2)),                                            # Pooling layer
    Conv2D(64, (3, 3), activation='relu'),                           # More filters
    MaxPooling2D((2, 2)),                                            # Pooling
    Flatten(),                                                       # Flatten to vector
    Dense(64, activation='relu'),                                    # Fully connected
    Dense(10, activation='softmax')                                  # Output layer
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = Sequential([
#       2     Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),  # Conv layer
#       3     MaxPooling2D((2, 2)),                                            # Pooling layer
#       4     Conv2D(64, (3, 3), activation='relu'),                           # More filters
#       5     MaxPooling2D((2, 2)),                                            # Pooling
#       6     Flatten(),                                                       # Flatten to vector
#       7     Dense(64, activation='relu'),                                    # Fully connected
#       8     Dense(10, activation='softmax')                                  # Output layer
#       9 ])
#
# NameError: name 'Sequential' is not defined

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model.compile(optimizer='adam',
#       2               loss='categorical_crossentropy',
#       3               metrics=['accuracy'])
#
# NameError: name 'model' is not defined

# %%
model.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))
#
# NameError: name 'model' is not defined

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 test_loss, test_accuracy = model.evaluate(x_test, y_test)
#       2 print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
#
# NameError: name 'model' is not defined
